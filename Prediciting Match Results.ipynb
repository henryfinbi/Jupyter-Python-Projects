# %% [markdown]
# # Checking for Missing Values

# %%
import pandas as pd

# %%
#dropping the index column
matches = pd.read_csv("matches.csv", index_col=0)

# %%
#viewing to see changes
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2023-08-13  16:30  Premier League  Matchweek 1  Sun  Away      D  1.0  1.0
# 1  2023-08-19  15:00  Premier League  Matchweek 2  Sat  Home      W  3.0  1.0
# 2  2023-08-27  16:30  Premier League  Matchweek 3  Sun  Away      W  2.0  1.0
# 3  2023-09-03  14:00  Premier League  Matchweek 4  Sun  Home      W  3.0  0.0
# 4  2023-09-16  12:30  Premier League  Matchweek 5  Sat  Away      W  3.0  1.0
#
#         opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0        Chelsea  ...  Match Report    NaN  13.0  1.0  17.8  0.0  0     0
# 1    Bournemouth  ...  Match Report    NaN  25.0  9.0  16.8  1.0  0     1
# 2  Newcastle Utd  ...  Match Report    NaN   9.0  4.0  17.2  1.0  0     0
# 3    Aston Villa  ...  Match Report    NaN  17.0  4.0  14.7  0.0  0     0
# 4         Wolves  ...  Match Report    NaN  16.0  5.0  15.8  0.0  0     0
#
#    season       team
# 0    2024  Liverpool
# 1    2024  Liverpool
# 2    2024  Liverpool
# 3    2024  Liverpool
# 4    2024  Liverpool
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1216, 27)

# %%
#Data was called Febrary  5, 2024 where most teams had played a max of 23 games in the 23/24 season.
#As of the time this code is being written, 23 games have been played in the 23/24 season, while the 22/23 season has been completed (38 games).
# 23/24 season = 23 matches * 20  squads while 22/23 = 38 matches * 20 squads
(23 * 20) + (38 * 20)
# Out:
# 1220

# %%
# At the time the code is being written, two fixture are outstanding. This means that 4 teams have played 22 matches.
# This is the cause of the difference in row size (1220-1216 = 4)
# The code below is used see each team in the league and howmany games theyve played in the two seasons at the point this code is being written.
matches["team"].value_counts().sum()

# some teams have only 38 games completed because they got relegated out of the league after the 22/23 season
# some other teams have only 23 games or less because they got promoted into the league in the 23/24 season.
# Out:
# 1216

# %% [markdown]
# ### ... ∴ no missing values

# %% [markdown]
# # Cleaning our Data For Machine Learning

# %%
#overview of the current data types before machine learning
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
#changing date to a more useful format
matches["date"] = pd.to_datetime(matches["date"])

# %%
#checking the change
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                       int64
# pkatt                    int64
# season                   int64
# team                    object
# dtype: object

# %% [markdown]
# # Creating Predictors for Machine Learning

# %%
#ranking Home/Away data in numerical form inorder to incorporate the idea of home advantage in our prediction
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
#transforming opposition data into numerical form
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
#creating an 'hour' column from the 'time' column 
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
#show days of week as numeric values
matches["day_code"] = matches["date"].dt.dayofweek

# %%
#displaying wins as 1's and losses/draws as 0's with new column
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2023-08-13  16:30  Premier League   Matchweek 1  Sun  Away      D  1.0
# 1  2023-08-19  15:00  Premier League   Matchweek 2  Sat  Home      W  3.0
# 2  2023-08-27  16:30  Premier League   Matchweek 3  Sun  Away      W  2.0
# 3  2023-09-03  14:00  Premier League   Matchweek 4  Sun  Home      W  3.0
# 4  2023-09-16  12:30  Premier League   Matchweek 5  Sat  Away      W  3.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      L  1.0
# 43 2023-05-08  20:00  Premier League  Matchweek 35  Mon  Away      L  3.0
# 44 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Home      L  0.0
# 45 2023-05-21  14:00  Premier League  Matchweek 37  Sun  Away      L  1.0
# 46 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Home      D  4.0
#
#      ga         opponent  ...   fk  pk  pkatt  season         team venue_code  \
# 0   1.0          Chelsea  ...  0.0   0      0    2024    Liverpool          0
# 1   1.0      Bournemouth  ...  1.0   0      1    2024    Liverpool          1
# 2   1.0    Newcastle Utd  ...  1.0   0      0    2024    Liverpool          0
# 3   0.0      Aston Villa  ...  0.0   0      0    2024    Liverpool          1
# 4   1.0           Wolves  ...  0.0   0      0    2024    Liverpool          0
# ..  ...              ...  ...  ...  ..    ...     ...          ...        ...
# 42  3.0    Newcastle Utd  ...  0.0   0      0    2023  Southampton          0
# 43  4.0  Nott'ham Forest  ...  0.0   1      1    2023  Southampton          0
# 44  2.0           Fulham  ...  0.0   0      0    2023  Southampton          1
# 45  3.0         Brighton  ...  1.0   0      0    2023  Southampton          0
# 46  4.0        Liverpool  ...  1.0   0      0    2023  Southampton          1
#
#    opp_code hour  day_code  target
# 0         6   16         6       0
# 1         2   15         5       1
# 2        16   16         6       1
# 3         1   14         6       1
# 4        22   12         5       1
# ..      ...  ...       ...     ...
# 42       16   14         6       0
# 43       17   20         0       0
# 44        9   15         5       0
# 45        4   14         6       0
# 46       12   16         6       0
#
# [1216 rows x 32 columns]

# %% [markdown]
# #  Creating the Initial Machine Learning Model

# %%
# RnadomForest is being used because it picks up non-linearities in the data eg; opponent codes dont rank opponents, it's just used to display them. Random Forest Classifier accounts for this. 
from sklearn.ensemble import RandomForestClassifier

# %%
#defining rf parameters
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
#defining the data range to be used for training
train = matches[matches["date"] < '2023-05-28']

# %%
#defining the data range to be used for testing
test = matches[matches["date"] > '2023-05-28']

# %%
#consolidating all the previously created predictors into a list
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
#fitting the random forest model inorder to predict our target
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
#generating predicitions
preds = rf.predict(test[predictors])

# %%
#a metric to check the accuracy of the match predicitons
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
# therefore when we predicted something will happen based on the test data, 59% of the time it happened
acc
# Out:
# 0.5899122807017544

# %%
# trying to see the situations where our accuracy was high vs low
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
#using a pandas crosstab to view our accuracy
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          216  60
# 1          127  53

# %%
# to see the percentage of time the teams actually won when we predicted a win
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4690265486725664

# %% [markdown]
# # Creating New Predictors to Improve our Prediction Model

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D  3.0
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  4.0
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W  6.0
# 6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W  3.0
# 10 2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W  6.0
# 12 2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home      W  4.0
# 14 2022-10-16  16:30  Premier League  Matchweek 11  Sun  Away      L  0.0
# 15 2022-10-22  15:00  Premier League  Matchweek 13  Sat  Home      W  3.0
# 17 2022-10-29  12:30  Premier League  Matchweek 14  Sat  Away      W  1.0
# 19 2022-11-05  15:00  Premier League  Matchweek 15  Sat  Home      W  2.0
# 21 2022-11-12  12:30  Premier League  Matchweek 16  Sat  Home      L  1.0
# 23 2022-12-28  20:00  Premier League  Matchweek 17  Wed  Away      W  3.0
# 24 2022-12-31  15:00  Premier League  Matchweek 18  Sat  Home      D  1.0
# 25 2023-01-05  20:00  Premier League  Matchweek 19  Thu  Away      W  1.0
# 28 2023-01-14  12:30  Premier League  Matchweek 20  Sat  Away      L  1.0
# 29 2023-01-19  20:00  Premier League   Matchweek 7  Thu  Home      W  4.0
# 30 2023-01-22  14:00  Premier League  Matchweek 21  Sun  Home      W  3.0
# 32 2023-02-05  16:30  Premier League  Matchweek 22  Sun  Away      L  0.0
# 33 2023-02-12  16:30  Premier League  Matchweek 23  Sun  Home      W  3.0
# 34 2023-02-15  19:30  Premier League  Matchweek 12  Wed  Away      W  3.0
# 35 2023-02-18  15:00  Premier League  Matchweek 24  Sat  Away      D  1.0
# 37 2023-02-25  17:30  Premier League  Matchweek 25  Sat  Away      W  4.0
# 39 2023-03-04  12:30  Premier League  Matchweek 26  Sat  Home      W  2.0
# 40 2023-03-11  17:30  Premier League  Matchweek 27  Sat  Away      W  1.0
# 43 2023-04-01  12:30  Premier League  Matchweek 29  Sat  Home      W  4.0
# 44 2023-04-08  17:30  Premier League  Matchweek 30  Sat  Away      W  4.0
# 46 2023-04-15  17:30  Premier League  Matchweek 31  Sat  Home      W  3.0
# 49 2023-04-26  20:00  Premier League  Matchweek 33  Wed  Home      W  4.0
# 50 2023-04-30  14:00  Premier League  Matchweek 34  Sun  Away      W  2.0
# 51 2023-05-03  20:00  Premier League  Matchweek 28  Wed  Home      W  3.0
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W  2.0
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W  3.0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W  1.0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D  1.0
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L  0.0
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# 23 2023-12-10  14:00  Premier League  Matchweek 16  Sun  Away      W  2.0
# 25 2023-12-16  15:00  Premier League  Matchweek 17  Sat  Home      D  2.0
# 26 2023-12-27  20:15  Premier League  Matchweek 19  Wed  Away      W  3.0
# 27 2023-12-30  15:00  Premier League  Matchweek 20  Sat  Home      W  2.0
# 29 2024-01-13  17:30  Premier League  Matchweek 21  Sat  Away      W  3.0
# 31 2024-01-31  19:30  Premier League  Matchweek 22  Wed  Home      W  3.0
# 32 2024-02-05  20:00  Premier League  Matchweek 23  Mon  Away      W  3.0
#
#      ga         opponent  ...   fk  pk  pkatt  season             team  \
# 1   0.0         West Ham  ...  1.0   1      1    2023  Manchester City
# 2   0.0      Bournemouth  ...  0.0   0      0    2023  Manchester City
# 3   3.0    Newcastle Utd  ...  1.0   0      0    2023  Manchester City
# 4   2.0   Crystal Palace  ...  0.0   0      0    2023  Manchester City
# 5   0.0  Nott'ham Forest  ...  0.0   0      0    2023  Manchester City
# 6   1.0      Aston Villa  ...  1.0   0      0    2023  Manchester City
# 9   0.0           Wolves  ...  0.0   0      0    2023  Manchester City
# 10  3.0   Manchester Utd  ...  1.0   0      0    2023  Manchester City
# 12  0.0      Southampton  ...  0.0   0      0    2023  Manchester City
# 14  1.0        Liverpool  ...  0.0   0      0    2023  Manchester City
# 15  1.0         Brighton  ...  0.0   1      1    2023  Manchester City
# 17  0.0   Leicester City  ...  1.0   0      0    2023  Manchester City
# 19  1.0           Fulham  ...  1.0   1      1    2023  Manchester City
# 21  2.0        Brentford  ...  0.0   0      0    2023  Manchester City
# 23  1.0     Leeds United  ...  0.0   0      0    2023  Manchester City
# 24  1.0          Everton  ...  0.0   0      0    2023  Manchester City
# 25  0.0          Chelsea  ...  0.0   0      0    2023  Manchester City
# 28  2.0   Manchester Utd  ...  0.0   0      0    2023  Manchester City
# 29  2.0        Tottenham  ...  1.0   0      0    2023  Manchester City
# 30  0.0           Wolves  ...  0.0   1      1    2023  Manchester City
# 32  1.0        Tottenham  ...  1.0   0      0    2023  Manchester City
# 33  1.0      Aston Villa  ...  1.0   1      1    2023  Manchester City
# 34  1.0          Arsenal  ...  0.0   0      0    2023  Manchester City
# 35  1.0  Nott'ham Forest  ...  2.0   0      0    2023  Manchester City
# 37  1.0      Bournemouth  ...  1.0   0      0    2023  Manchester City
# 39  0.0    Newcastle Utd  ...  2.0   0      0    2023  Manchester City
# 40  0.0   Crystal Palace  ...  1.0   1      1    2023  Manchester City
# 43  1.0        Liverpool  ...  1.0   0      0    2023  Manchester City
# 44  1.0      Southampton  ...  0.0   1      1    2023  Manchester City
# 46  1.0   Leicester City  ...  0.0   1      1    2023  Manchester City
# 49  1.0          Arsenal  ...  0.0   0      0    2023  Manchester City
# 50  1.0           Fulham  ...  0.0   1      1    2023  Manchester City
# 51  0.0         West Ham  ...  0.0   0      0    2023  Manchester City
# 52  1.0     Leeds United  ...  2.0   0      1    2023  Manchester City
# 54  0.0          Everton  ...  2.0   0      0    2023  Manchester City
# 56  0.0          Chelsea  ...  0.0   0      0    2023  Manchester City
# 57  1.0         Brighton  ...  0.0   0      0    2023  Manchester City
# 58  1.0        Brentford  ...  0.0   0      0    2023  Manchester City
# 1   0.0          Burnley  ...  0.0   0      0    2024  Manchester City
# 3   0.0    Newcastle Utd  ...  0.0   0      0    2024  Manchester City
# 4   1.0    Sheffield Utd  ...  2.0   0      1    2024  Manchester City
# 5   1.0           Fulham  ...  0.0   1      1    2024  Manchester City
# 6   1.0         West Ham  ...  1.0   0      0    2024  Manchester City
# 8   0.0  Nott'ham Forest  ...  2.0   0      0    2024  Manchester City
# 10  2.0           Wolves  ...  1.0   0      0    2024  Manchester City
# 12  1.0          Arsenal  ...  0.0   0      0    2024  Manchester City
# 13  1.0         Brighton  ...  1.0   0      0    2024  Manchester City
# 15  0.0   Manchester Utd  ...  2.0   1      1    2024  Manchester City
# 16  1.0      Bournemouth  ...  0.0   0      0    2024  Manchester City
# 18  4.0          Chelsea  ...  1.0   1      1    2024  Manchester City
# 19  1.0        Liverpool  ...  1.0   0      0    2024  Manchester City
# 21  3.0        Tottenham  ...  0.0   0      0    2024  Manchester City
# 22  1.0      Aston Villa  ...  0.0   0      0    2024  Manchester City
# 23  1.0       Luton Town  ...  1.0   0      0    2024  Manchester City
# 25  2.0   Crystal Palace  ...  0.0   0      0    2024  Manchester City
# 26  1.0          Everton  ...  1.0   1      1    2024  Manchester City
# 27  0.0    Sheffield Utd  ...  0.0   0      0    2024  Manchester City
# 29  2.0    Newcastle Utd  ...  2.0   0      0    2024  Manchester City
# 31  1.0          Burnley  ...  1.0   0      0    2024  Manchester City
# 32  1.0        Brentford  ...  0.0   0      0    2024  Manchester City
#
#    venue_code opp_code hour  day_code  target
# 1           0       21   16         6       1
# 2           1        2   15         5       1
# 3           0       16   16         6       0
# 4           1        7   15         5       1
# 5           1       17   19         2       1
# 6           0        1   17         5       0
# 9           0       22   12         5       1
# 10          1       15   14         6       1
# 12          1       19   15         5       1
# 14          0       12   16         6       0
# 15          1        4   15         5       1
# 17          0       11   12         5       1
# 19          1        9   15         5       1
# 21          1        3   12         5       0
# 23          0       10   20         2       1
# 24          1        8   15         5       0
# 25          0        6   20         3       1
# 28          0       15   12         5       0
# 29          1       20   20         3       1
# 30          1       22   14         6       1
# 32          0       20   16         6       0
# 33          1        1   16         6       1
# 34          0        0   19         2       1
# 35          0       17   15         5       0
# 37          0        2   17         5       1
# 39          1       16   12         5       1
# 40          0        7   17         5       1
# 43          1       12   12         5       1
# 44          0       19   17         5       1
# 46          1       11   17         5       1
# 49          1        0   20         2       1
# 50          0        9   14         6       1
# 51          1       21   20         2       1
# 52          1       10   15         5       1
# 54          0        8   14         6       1
# 56          1        6   16         6       1
# 57          0        4   20         2       0
# 58          0        3   16         6       0
# 1           0        5   20         4       1
# 3           1       16   20         5       1
# 4           0       18   14         6       1
# 5           1        9   15         5       1
# 6           0       21   15         5       1
# 8           1       17   15         5       1
# 10          0       22   15         5       0
# 12          0        0   16         6       0
# 13          1        4   15         5       1
# 15          0       15   15         6       1
# 16          1        2   15         5       1
# 18          0        6   16         6       0
# 19          1       12   12         5       0
# 21          1       20   16         6       0
# 22          0        1   20         2       0
# 23          0       13   14         6       1
# 25          1        7   15         5       0
# 26          0        8   20         2       1
# 27          1       18   15         5       1
# 29          0       16   17         5       1
# 31          1        5   19         2       1
# 32          0        3   20         0       1
#
# [60 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols).head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W  6.0  0.0
# 6  2022-09-03  17:30  Premier League  Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2022-09-17  12:30  Premier League  Matchweek 8  Sat  Away      W  3.0  0.0
# 10 2022-10-02  14:00  Premier League  Matchweek 9  Sun  Home      W  6.0  3.0
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4    Crystal Palace  ...         5       1    3.000000    1.000000  17.666667
# 5   Nott'ham Forest  ...         2       1    3.666667    1.666667  19.333333
# 6       Aston Villa  ...         5       0    4.333333    1.666667  18.666667
# 9            Wolves  ...         5       1    3.666667    1.000000  16.000000
# 10   Manchester Utd  ...         6       1    3.333333    0.333333  15.333333
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     6.000000    17.466667   0.666667    0.333333       0.333333
# 5     7.333333    15.933333   0.333333    0.000000       0.000000
# 6     8.000000    15.033333   0.333333    0.000000       0.000000
# 9     6.000000    15.233333   0.333333    0.000000       0.000000
# 10    6.666667    17.000000   0.333333    0.000000       0.000000
#
# [5 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 3  2022-08-27  17:30  Premier League   Matchweek 4
#                         4  2022-08-31  19:30  Premier League   Matchweek 5
#                         5  2022-09-04  16:30  Premier League   Matchweek 6
#                         7  2022-09-18  12:00  Premier League   Matchweek 8
#                         8  2022-10-01  12:30  Premier League   Matchweek 9
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 20 2023-12-27  19:30  Premier League  Matchweek 19
#                         21 2023-12-30  15:00  Premier League  Matchweek 20
#                         24 2024-01-22  19:45  Premier League  Matchweek 21
#                         26 2024-02-01  20:15  Premier League  Matchweek 22
#                         27 2024-02-04  14:00  Premier League  Matchweek 23
#
#                             day venue result   gf   ga        opponent  ...  \
# team                                                                    ...
# Arsenal                 3   Sat  Home      W  2.0  1.0          Fulham  ...
#                         4   Wed  Home      W  2.0  1.0     Aston Villa  ...
#                         5   Sun  Away      L  1.0  3.0  Manchester Utd  ...
#                         7   Sun  Away      W  3.0  0.0       Brentford  ...
#                         8   Sat  Home      W  3.0  1.0       Tottenham  ...
# ...                         ...   ...    ...  ...  ...             ...  ...
# Wolverhampton Wanderers 20  Wed  Away      W  4.0  1.0       Brentford  ...
#                         21  Sat  Home      W  3.0  0.0         Everton  ...
#                         24  Mon  Away      D  0.0  0.0        Brighton  ...
#                         26  Thu  Home      L  3.0  4.0  Manchester Utd  ...
#                         27  Sun  Away      W  4.0  2.0         Chelsea  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 3          5       1    3.000000    0.666667
#                         4          2       1    3.000000    1.000000
#                         5          6       0    2.333333    0.666667
#                         7          6       1    1.666667    1.666667
#                         8          5       1    2.000000    1.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 20         2       1    1.000000    1.666667
#                         21         5       1    2.000000    1.666667
#                         24         0       0    3.000000    0.666667
#                         26         3       0    2.333333    0.333333
#                         27         6       1    2.000000    1.333333
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 3   14.333333    5.000000    14.133333   0.333333
#                         4   18.333333    7.000000    14.433333   0.333333
#                         5   19.333333    7.333333    15.533333   0.666667
#                         7   20.000000    6.333333    16.800000   1.000000
#                         8   17.000000    6.000000    17.700000   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 20  12.666667    4.333333    17.466667   0.333333
#                         21  13.000000    4.666667    18.333333   0.333333
#                         24  12.333333    5.666667    15.966667   0.333333
#                         26  10.333333    4.666667    16.600000   0.000000
#                         27  11.666667    4.666667    16.200000   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 3     0.000000       0.000000
#                         4     0.000000       0.000000
#                         5     0.000000       0.000000
#                         7     0.000000       0.000000
#                         8     0.000000       0.000000
# ...                                ...            ...
# Wolverhampton Wanderers 20    0.000000       0.000000
#                         21    0.000000       0.000000
#                         24    0.000000       0.000000
#                         26    0.000000       0.000000
#                         27    0.333333       0.333333
#
# [1147 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-05-28']
    test = data[data["date"] > '2023-05-28']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
#it improved by about 10 points.
# Out:
# 0.5363636363636364

# %%
combined
# Out:
#       actual  predicted
# 35         1          1
# 36         1          1
# 37         0          1
# 38         1          1
# 39         1          1
# ...      ...        ...
# 1142       1          0
# 1143       1          1
# 1144       0          1
# 1145       0          0
# 1146       1          0
#
# [447 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 35         1          1 2023-08-12                  Arsenal  Nott'ham Forest
# 36         1          1 2023-08-21                  Arsenal   Crystal Palace
# 37         0          1 2023-08-26                  Arsenal           Fulham
# 38         1          1 2023-09-03                  Arsenal   Manchester Utd
# 39         1          1 2023-09-17                  Arsenal          Everton
# ...      ...        ...        ...                      ...              ...
# 1142       1          0 2023-12-27  Wolverhampton Wanderers        Brentford
# 1143       1          1 2023-12-30  Wolverhampton Wanderers          Everton
# 1144       0          1 2024-01-22  Wolverhampton Wanderers         Brighton
# 1145       0          0 2024-02-01  Wolverhampton Wanderers   Manchester Utd
# 1146       1          0 2024-02-04  Wolverhampton Wanderers          Chelsea
#
#      result
# 35        W
# 36        W
# 37        D
# 38        W
# 39        W
# ...     ...
# 1142      W
# 1143      W
# 1144      D
# 1145      L
# 1146      W
#
# [447 rows x 6 columns]

# %%
#Things to do to improve
#use all competitions data
#involve other unused columns
